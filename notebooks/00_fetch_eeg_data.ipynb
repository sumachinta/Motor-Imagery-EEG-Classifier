# %%
from pathlib import Path
import numpy as np
import sys, importlib.util, os
parentPath = Path.cwd().parent
sys.path.insert(0, str(parentPath))

# %%
from mne.datasets import eegbci

subjects = np.arange(1, 110)#[1,2]
runs_mi = [3,4,7,8,11,12] # fists L/R; 4/8/12 are IMAGERY, 3/7/11 are EXECUTION
dataPath = Path(f"{parentPath}/data/raw")
files = eegbci.load_data(subjects=subjects, runs=runs_mi, path=dataPath, update_path=True)
len(files), files[:2]
# Out:
# ...
# ...
# ...
# Download complete in 52m15s (1366.9 MB)
# (654,
#  [PosixPath('/Users/sumachinta/Library/CloudStorage/OneDrive-CytoTronics/github/Motor-Imagery-EEG-Classifier/data/raw/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R03.edf'),
#   PosixPath('/Users/sumachinta/Library/CloudStorage/OneDrive-CytoTronics/github/Motor-Imagery-EEG-Classifier/data/raw/MNE-eegbci-data/files/eegmmidb/1.0.0/S001/S001R04.edf')])
